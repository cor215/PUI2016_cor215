# %% [markdown]
# # Written by Christian Rosado
# # NYU CUSP PUI2016
# # Assignment 1 Homework 3

# %%
from __future__ import print_function
import pylab as pl
from scipy.optimize import curve_fit, minimize
    
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Chisquare Distribution Example Given in Class

# %%
mymean = 100

# %%
df = mymean

# %%
import numpy as np
md = {}
# md is an empty disctionary
md['chisq'] = np.random.chisquare(df, size=100)
# md now is a dictionary with one object: an array by the key 'chisq'
pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ### Figure 1: Chi sq distribution: df = 100, N=100

# %% [markdown]
# ## let numpy calculate what the mean and stdev of this distribution are

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 101.21, standard deviation: 13.64

# %% [markdown]
# ## Now let's do it for 100 Chisq distributions
# we want distributions of different sizes (all integers between 10 and 2000)

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)

print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['chisq'] = {} 

for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)
    
md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure 2: [describe what you see and how it relates to the law of large numbers]

# %% [markdown]
# # now the histogram of the mean of all samples:
# ## this requires some data wrangling, since i put the data in a dictionary which is a user friendly data structure, but perhaps not the most machine friendly one
#
# a coder friendly, though not terribly pythonic way to do it is to append each mean in a list in a for loop, and then hist that. be careful: if your data size gets large this becomes a very bad idea!!

# %%
allmeans = list(md['chisq']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# ## Figure 3: [...]

# %% [markdown]
# # Do it for the Normal distribution

# %%
##your code here...

md = {}

md['normal'] = np.random.normal(mymean, 10, size=10000)

pl.hist(md['normal'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("Normal mean: %.2f, standard deviation: %.2f"%(md['normal'].mean(), md['normal'].std()))
# Out:
# Normal mean: 99.97, standard deviation: 9.94

# %%
md['normal'] = {} 



for n in mysize:
    md['normal'][n] = np.random.normal(df, size = n)
    
   

md['normal']['means'] = {}
normal_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['normal']:
    if not type(nn) == str:
        md['normal']['means'][nn] = md['normal'][nn].mean()
        #and plot it
        normal_mu_n.plot(nn, md['normal']['means'][nn], 'o')
        normal_mu_n.set_xlabel('sample size', fontsize=18)
        normal_mu_n.set_ylabel('sample mean', fontsize=18)
        normal_mu_n.set_title('Normal', fontsize=18)
        normal_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %%
allmeans = list(md['normal']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# # Do it for the Poisson distribution

# %%
##your code here...

md = {}

md['poisson'] = np.random.poisson(mymean, size=10000)

pl.hist(md['poisson'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("Posison mean: %.2f, standard deviation: %.2f"%(md['poisson'].mean(), md['poisson'].std()))
# Out:
# Posison mean: 100.05, standard deviation: 9.93

# %%
md['poisson'] = {} 


for n in mysize:
    md['poisson'][n] = np.random.normal(df, size = n)
    

md['poisson']['means'] = {}
poisson_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['poisson']:
    if not type(nn) == str:
        md['poisson']['means'][nn] = md['poisson'][nn].mean()
        #and plot it
        poisson_mu_n.plot(nn, md['poisson']['means'][nn], 'o')
        poisson_mu_n.set_xlabel('sample size', fontsize=18)
        poisson_mu_n.set_ylabel('sample mean', fontsize=18)
        poisson_mu_n.set_title('Poisson', fontsize=18)
        poisson_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %%
allmeans = list(md['poisson']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# # Do it for the Binomial distribution

# %%
##your code here... 

md = {}

md['binomial'] = np.random.binomial(200, .5, size=10000)

pl.hist(md['binomial'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("Binomial mean: %.2f, standard deviation: %.2f"%(md['binomial'].mean(), md['binomial'].std()))
# Out:
# Binomial mean: 100.10, standard deviation: 6.95

# %%
md['binomial'] = {} 



for n in mysize:
    md['binomial'][n] = np.random.binomial(200, 0.5, size = n)
    
   

md['binomial']['means'] = {}
binomial_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['binomial']:
    if not type(nn) == str:
        md['binomial']['means'][nn] = md['binomial'][nn].mean()
        #and plot it
        binomial_mu_n.plot(nn, md['binomial']['means'][nn], 'o')
        binomial_mu_n.set_xlabel('sample size', fontsize=18)
        binomial_mu_n.set_ylabel('sample mean', fontsize=18)
        binomial_mu_n.set_title('Binomial', fontsize=18)
        binomial_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %%
allmeans = list(md['binomial']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# # Do it for another distribution

# %%
##your code here...

md = {}

md['logistic'] = np.random.logistic(0, 1, size=10000)

pl.hist(md['logistic'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("Logistic mean: %.2f, standard deviation: %.2f"%(md['logistic'].mean(), md['logistic'].std()))
# Out:
# Logistic mean: 0.00, standard deviation: 1.81

# %%
md['logistic'] = {} 



for n in mysize:
    md['logistic'][n] = np.random.logistic(100, 1, size=10000)
    
   

md['logistic']['means'] = {}
logistic_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['logistic']:
    if not type(nn) == str:
        md['logistic']['means'][nn] = md['logistic'][nn].mean()
        #and plot it
        logistic_mu_n.plot(nn, md['logistic']['means'][nn], 'o')
        logistic_mu_n.set_xlabel('sample size', fontsize=18)
        logistic_mu_n.set_ylabel('sample mean', fontsize=18)
        logistic_mu_n.set_title('Logistic', fontsize=18)
        logistic_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %%
allmeans = list(md['logistic']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
